# %% [markdown]
# Type Casting

# %%
i = 50
f = 55.5
s = "12qwerty"
si = "123"
sf = "1.2"

new_s = str(i) # int to string
print(new_s)
f = int(f) # float to int - without point
print(f)

new_s_from_float = str(f) # float to str - without point
print(new_s_from_float)

# new_i = int(s) # ValueError: invalid literal for int()
new_i = int(si) # string to int
# Out:
# 50
# 55
# 55 gggg

# %% [markdown]
# Check datatype

# %%
print(type(i))
# Out:
# <class 'int'>
